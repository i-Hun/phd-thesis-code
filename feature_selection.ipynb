# %%
import pandas as pd
import csv
import re
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 300
pd.options.display.max_rows = 300

# %matplotlib inline

# %%
df = pd.read_msgpack("../data/full_df.msgpack")

# %%
df.shape
# Out:
# (14590, 64)

# %%
df.head()
# Out:
#     about_whole_nation_recoded_value about_whole_nation_recoded_label  \
# 0                                1.0                              yes
# 5                                NaN                              NaN
# 8                                0.0                               no
# 11                               NaN                              NaN
# 12                               0.0                               no
#
#          assessor comment                 date  document.id  \
# 0      skuchilina     NaN  2016-09-25 20:06:34          883
# 5   Oleg Nagornyy     NaN  2016-08-01 09:25:19         2942
# 8           Dasha     NaN  2016-07-10 22:58:24         9333
# 11        Tatiana     NaN  2016-06-22 14:28:27         9346
# 12  Oleg Nagornyy     NaN  2016-07-27 14:37:31        12039
#
#     do_text_make_sense_raw_value do_text_make_sense_raw_label  \
# 0                              1                          yes
# 5                              1                          yes
# 8                              1                          yes
# 11                             1                          yes
# 12                             1                          yes
#
#     encourage_aggression_meaning_value encourage_aggression_meaning_label  \
# 0                                  0.0                                 no
# 5                                  NaN                                NaN
# 8                                  0.0                                 no
# 11                                 NaN                                NaN
# 12                                 0.0                                 no
#
#    eth_group_to_code  has_eth_conflict_raw_value has_eth_conflict_raw_label  \
# 0            тибетец                         0.0                         no
# 5              помор                         0.0                         no
# 8             калмык                         0.0                         no
# 11          украинец                         0.0                         no
# 12          кавказец                         0.0                         no
#
#     has_ethnonym_raw_value has_ethnonym_raw_label  \
# 0                      2.0                several
# 5                      1.0                    one
# 8                      1.0                    one
# 11                     1.0                    one
# 12                     1.0                    one
#
#     has_pos_eth_interaction_raw_value has_pos_eth_interaction_raw_label  \
# 0                                 1.0                               yes
# 5                                 0.0                                no
# 8                                 0.0                                no
# 11                                0.0                                no
# 12                                0.0                                no
#
#     has_topic_culture_value has_topic_culture_label  \
# 0                       1.0                     yes
# 5                       0.0                      no
# 8                       0.0                      no
# 11                      0.0                      no
# 12                      0.0                      no
#
#     has_topic_daily_routine_value has_topic_daily_routine_label  \
# 0                             0.0                            no
# 5                             1.0                           yes
# 8                             0.0                            no
# 11                            0.0                            no
# 12                            1.0                           yes
#
#     has_topic_economics_value has_topic_economics_label  \
# 0                         0.0                        no
# 5                         0.0                        no
# 8                         0.0                        no
# 11                        0.0                        no
# 12                        0.0                        no
#
#     has_topic_ethicity_value has_topic_ethicity_label  \
# 0                        1.0                      yes
# 5                        0.0                       no
# 8                        1.0                      yes
# 11                       0.0                       no
# 12                       1.0                      yes
#
#     has_topic_history_value has_topic_history_label  has_topic_humour_value  \
# 0                       0.0                      no                     0.0
# 5                       0.0                      no                     0.0
# 8                       0.0                      no                     1.0
# 11                      0.0                      no                     0.0
# 12                      0.0                      no                     0.0
#
#    has_topic_humour_label  has_topic_migration_value  \
# 0                      no                        0.0
# 5                      no                        0.0
# 8                     yes                        0.0
# 11                     no                        0.0
# 12                     no                        0.0
#
#    has_topic_migration_label  has_topic_other_value has_topic_other_label  \
# 0                         no                    0.0                    no
# 5                         no                    0.0                    no
# 8                         no                    0.0                    no
# 11                        no                    0.0                    no
# 12                        no                    0.0                    no
#
#     has_topic_politics_value has_topic_politics_label  \
# 0                        0.0                       no
# 5                        0.0                       no
# 8                        0.0                       no
# 11                       1.0                      yes
# 12                       0.0                       no
#
#     has_topic_religion_value has_topic_religion_label  \
# 0                        0.0                       no
# 5                        0.0                       no
# 8                        0.0                       no
# 11                       0.0                       no
# 12                       0.0                       no
#
#     has_topic_society_social_value has_topic_society_social_label  \
# 0                              0.0                             no
# 5                              0.0                             no
# 8                              0.0                             no
# 11                             0.0                             no
# 12                             0.0                             no
#
#     is_ethicity_aggressor_meaning_value is_ethicity_aggressor_meaning_label  \
# 0                                   NaN                          irrelevant
# 5                                   NaN                                 NaN
# 8                                   NaN                          irrelevant
# 11                                  NaN                                 NaN
# 12                                  NaN                          irrelevant
#
#     is_ethicity_dangerous_meaning_value is_ethicity_dangerous_meaning_label  \
# 0                                   0.0                                  no
# 5                                   NaN                                 NaN
# 8                                   0.0                                  no
# 11                                  NaN                                 NaN
# 12                                  0.0                                  no
#
#     is_ethicity_superior_meaning_value is_ethicity_superior_meaning_label  \
# 0                                  NaN                              irrel
# 5                                  NaN                                NaN
# 8                                  NaN                              irrel
# 11                                 NaN                                NaN
# 12                                 NaN                              irrel
#
#     is_text_neg_raw_value is_text_neg_raw_label  is_text_positive_raw_value  \
# 0                     0.0                    no                         1.0
# 5                     0.0                    no                         2.0
# 8                     0.0                    no                         1.0
# 11                    1.0                  weak                         0.0
# 12                    1.0                  weak                         0.0
#
#    is_text_positive_raw_label  opinion_about_ethnonym_recoded_value  \
# 0                        weak                                   1.0
# 5                      strong                                   NaN
# 8                        weak                                   1.0
# 11                         no                                   NaN
# 12                         no                                   1.0
#
#    opinion_about_ethnonym_recoded_label  represent_ethicity_meaning_value  \
# 0                               neutral                               0.0
# 5                                   NaN                               NaN
# 8                               neutral                               0.0
# 11                                  NaN                               NaN
# 12                              neutral                               0.0
#
#    represent_ethicity_meaning_label seed_eth_group source_x  stage source_y  \
# 0                                no         монгол       vk      1       vk
# 5                               NaN          помор       vk      1       vk
# 8                                no         калмык       vk      1       vk
# 11                              NaN       украинец       vk      1       vk
# 12                               no       кавказец       vk      1       vk
#
#                                           source_text  \
# 0   Музыка Китая – одна из древнейших в мировой му...
# 5   Письма это такая редкость сейчас... Но их безу...
# 8   Счастливая калмычка, не та, у которой много по...
# 11  Валерий Коновалюк требует наказать виновных в ...
# 12  МАКСИМАЛЬНЫЙ РЕПОСТ: Друзья, позавчера днём на...
#
#                                             lemm_text         city  \
# 0   музыка китай древний мирова музыкальный культу...     Владимир
# 5   письмо такать редкость безумно приятно особенн...       Ковров
# 8   счастливый калмычка поклонник кушать толстеть ...       Элиста
# 11  валерий коновалюк требовать наказывать виновны...  Александров
# 12  максимальный репост друг позавчера день каде т...      Воронеж
#
#                   region created_date     instance_id  \
# 0   Владимирская область   2015-08-13     883_тибетец
# 5   Владимирская область   2014-11-08      2942_помор
# 8               Калмыкия   2015-04-27     9333_калмык
# 11  Владимирская область   2014-05-03   9346_украинец
# 12   Воронежская область   2012-12-24  12039_кавказец
#
#            aggregated_groups
# 0                 Южная Азия
# 5                   Прибалты
# 8   Тюркские народы до Урала
# 11         Восточные славяне
# 12            Народы Кавказа

# %%
df.drop_duplicates(subset="document.id", inplace=True)

# %%
df[["document.id", "source_text", "lemm_text"]].to_csv("../Feature selection/texts_for_max.csv", index=False)
